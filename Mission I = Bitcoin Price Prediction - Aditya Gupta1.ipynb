# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
bit = pd.read_csv('bitcoin_dataset.csv')
bit.head()
# Out:
#         Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2/17/2010               0.0           2043200.0             0.0
# 1  2/18/2010               0.0           2054650.0             0.0
# 2  2/19/2010               0.0           2063600.0             0.0
# 3  2/20/2010               0.0           2074700.0             0.0
# 4  2/21/2010               0.0           2085400.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000235
# 1               0.0              0.0            0.000241
# 2               0.0              0.0            0.000228
# 3               0.0              0.0            0.000218
# 4               0.0              0.0            0.000234
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                      0                           1.0
# 1                      0                           1.0
# ...

# %%
bit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906 entries, 0 to 2905
# Data columns (total 24 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Date                                                 2906 non-null   object
#  1   btc_market_price                                     2906 non-null   float64
#  2   btc_total_bitcoins                                   2879 non-null   float64
#  3   btc_market_cap                                       2906 non-null   float64
#  4   btc_trade_volume                                     2885 non-null   float64
#  5   btc_blocks_size                                      2877 non-null   float64
#  6   btc_avg_block_size                                   2906 non-null   float64
#  7   btc_n_orphaned_blocks                                2906 non-null   int64
# ...

# %%
bit.describe()
# Out:
#        btc_market_price  btc_total_bitcoins  btc_market_cap  btc_trade_volume  \
# count       2906.000000        2.879000e+03    2.906000e+03      2.885000e+03
# mean         839.104218        1.151138e+07    1.344352e+10      7.398381e+07
# std         2304.972497        4.200024e+06    3.866841e+10      2.924228e+08
# min            0.000000        2.043200e+06    0.000000e+00      0.000000e+00
# 25%            6.653465        8.485300e+06    5.363081e+07      2.916456e+05
# 50%          235.130000        1.243115e+07    3.346869e+09      1.001414e+07
# 75%          594.191164        1.520051e+07    8.075525e+09      2.834038e+07
# max        19498.683330        1.683769e+07    3.270000e+11      5.352016e+09
#
#        btc_blocks_size  btc_avg_block_size  btc_n_orphaned_blocks  \
# count      2877.000000         2906.000000            2906.000000
# mean      35505.502848            0.350366               0.364074
# std       43618.633821            0.353168               0.842259
# ...

# %% [markdown]
# ### MicroTask 2 : What is the 1024th value in the column 'btc_market_price"?

# %%
bit.loc[1024, "btc_market_price"]
# Out:
# 13.68

# %% [markdown]
# ### The 1024th value in the column 'btc_market_price" is 13.68

# %% [raw]
# bit.iloc[1023:1026,:]

# %% [markdown]
# ### Micro Task 3 : Which feature shows the perfect correlation with 'btc_market_price' i.e. has a pearson correlation equal to 1?

# %%
# Creating the heatmap
plt.figure(figsize = (15,15))
cor = bit.corr()
sns.heatmap(cor, annot = True)
plt.show()

# %% [markdown]
# ### According to heatmap, the feature which shows the perfect correlation with 'btc_market_price' is 'btc_market_cap'.

# %%
### Jointplot
sns.jointplot(data = bit, x = 'btc_market_cap', y = 'btc_market_price', kind = 'scatter')
plt.show()

# %% [markdown]
# ### Micro Task 4 : What function in pandas allows you to fill cells in a column that have NaN values?

# %%
bit.isnull().sum()
# Out:
# Date                                                    0
# btc_market_price                                        0
# btc_total_bitcoins                                     27
# btc_market_cap                                          0
# btc_trade_volume                                       21
# btc_blocks_size                                        29
# btc_avg_block_size                                      0
# btc_n_orphaned_blocks                                   0
# btc_n_transactions_per_block                            0
# btc_median_confirmation_time                           12
# btc_hash_rate                                           0
# btc_difficulty                                         16
# btc_miners_revenue                                      0
# btc_transaction_fees                                   10
# btc_cost_per_transaction_percent                        0
# btc_cost_per_transaction                                0
# ...

# %%
bit.isnull().sum()[bit.isnull().sum()!=0]
# Out:
# btc_total_bitcoins              27
# btc_trade_volume                21
# btc_blocks_size                 29
# btc_median_confirmation_time    12
# btc_difficulty                  16
# btc_transaction_fees            10
# dtype: int64

# %%
bit.columns
# Out:
# Index(['Date', 'btc_market_price', 'btc_total_bitcoins', 'btc_market_cap',
#        'btc_trade_volume', 'btc_blocks_size', 'btc_avg_block_size',
#        'btc_n_orphaned_blocks', 'btc_n_transactions_per_block',
#        'btc_median_confirmation_time', 'btc_hash_rate', 'btc_difficulty',
#        'btc_miners_revenue', 'btc_transaction_fees',
#        'btc_cost_per_transaction_percent', 'btc_cost_per_transaction',
#        'btc_n_unique_addresses', 'btc_n_transactions',
#        'btc_n_transactions_total', 'btc_n_transactions_excluding_popular',
#        'btc_n_transactions_excluding_chains_longer_than_100',
#        'btc_output_volume', 'btc_estimated_transaction_volume',
#        'btc_estimated_transaction_volume_usd'],
#       dtype='object')

# %%
bit1=bit[['btc_market_cap', 'btc_n_transactions','btc_miners_revenue','btc_cost_per_transaction','btc_difficulty','btc_hash_rate','btc_cost_per_transaction_percent','btc_market_price']]

# %%
bit1.head()
# Out:
#    btc_market_cap  btc_n_transactions  btc_miners_revenue  \
# 0             0.0                 244                 0.0
# 1             0.0                 235                 0.0
# 2             0.0                 183                 0.0
# 3             0.0                 224                 0.0
# 4             0.0                 218                 0.0
#
#    btc_cost_per_transaction  btc_difficulty  btc_hash_rate  \
# 0                       0.0        2.527738       0.000029
# 1                       0.0        2.527738       0.000029
# 2                       0.0        2.527738       0.000023
# 3                       0.0        2.527738       0.000028
# 4                       0.0        2.527738       0.000027
#
#    btc_cost_per_transaction_percent  btc_market_price
# 0                         31.781022               0.0
# 1                        154.463801               0.0
# 2                       1278.516635               0.0
# ...

# %%
bit1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906 entries, 0 to 2905
# Data columns (total 8 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   btc_market_cap                    2906 non-null   float64
#  1   btc_n_transactions                2906 non-null   int64
#  2   btc_miners_revenue                2906 non-null   float64
#  3   btc_cost_per_transaction          2906 non-null   float64
#  4   btc_difficulty                    2890 non-null   float64
#  5   btc_hash_rate                     2906 non-null   float64
#  6   btc_cost_per_transaction_percent  2906 non-null   float64
#  7   btc_market_price                  2906 non-null   float64
# dtypes: float64(7), int64(1)
# memory usage: 181.8 KB

# %%
# Identifying null values
bit1.isnull().sum()
# Out:
# btc_market_cap                       0
# btc_n_transactions                   0
# btc_miners_revenue                   0
# btc_cost_per_transaction             0
# btc_difficulty                      16
# btc_hash_rate                        0
# btc_cost_per_transaction_percent     0
# btc_market_price                     0
# dtype: int64

# %%
bit1.isnull().sum()[bit1.isnull().sum()!=0] # There are 16 null values in 'btc_difficulty'
# Out:
# btc_difficulty    16
# dtype: int64

# %%
# Replacing the null values with mean
bit1['btc_difficulty'].describe()
# Out:
# count    2.890000e+03
# mean     1.606360e+11
# std      3.725159e+11
# min      2.527738e+00
# 25%      1.591075e+06
# 50%      2.193848e+09
# 75%      1.130000e+11
# max      2.600000e+12
# Name: btc_difficulty, dtype: float64

# %%
mean = bit1.btc_difficulty.mean()
mean
# Out:
# 160635963100.33813

# %%
bit1['btc_difficulty'].fillna(mean, inplace=True)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\pandas\core\series.py:4517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
bit1['btc_difficulty'].isnull().sum()/bit1.shape[0]*100
# Out:
# 0.0

# %%
bit1.isnull().sum()
# Out:
# btc_market_cap                      0
# btc_n_transactions                  0
# btc_miners_revenue                  0
# btc_cost_per_transaction            0
# btc_difficulty                      0
# btc_hash_rate                       0
# btc_cost_per_transaction_percent    0
# btc_market_price                    0
# dtype: int64

# %% [markdown]
# ### The function in pandas which allows us to fill cells in a column that have NaN values is fillna().

# %% [markdown]
# ### Micro Task 5 : What is the MSE of your model?

# %%
# Model Formulation and Prediction
X = bit1.drop('btc_market_price',axis=1)
Y = bit1['btc_market_price']

# %%
# Train Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, random_state = 0)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (2324, 7)
# (582, 7)
# (2324,)
# (582,)

# %%
# Model Building
from sklearn.linear_model import LinearRegression
lreg = LinearRegression()
lreg.fit(X_train, Y_train)
# Training & Testing Score
print('Training Score: ', round(lreg.score(X_train, Y_train)*100,2),'%')
print('Testing Score: ', round(lreg.score(X_test, Y_test)*100,2))
# Out:
# Training Score:  99.99 %
# Testing Score:  99.99

# %%
# Prediction
y_predict = lreg.predict(X_test)
y_predict
# Out:
# array([ 1.52040314e+01,  2.72287268e+02,  1.09036534e+02,  4.63951981e+02,
#         3.92542161e+00,  4.79859114e+01,  1.89526766e+00,  2.48643856e+03,
#         7.95899962e+02,  1.15184031e+01,  9.73413737e+00, -3.98656494e+00,
#         5.46332891e+03,  6.28569217e+00, -7.20739637e+00,  1.22185979e+01,
#         2.43493788e+01,  3.00537191e+02,  8.84775968e+02,  7.31568506e+01,
#        -1.30593175e+01,  8.24754204e+01,  2.60347670e+02,  8.09642519e-01,
#        -3.24074631e-01, -1.30589823e+01,  7.62635877e+00,  8.82230502e+00,
#         6.46407683e+02, -8.10697158e+00,  1.14275938e+01,  1.15651849e+01,
#         4.75901435e+01,  7.25390441e+00,  2.44366507e+02,  1.05406890e+03,
#         4.15822667e+02,  4.35386079e+02,  2.46131828e+02,  1.14942658e+02,
#         6.02473201e+02,  1.24162913e+02,  1.58911615e+01,  5.35712015e+02,
#         2.23704637e+01,  6.48776586e+02,  3.22808447e+02,  2.81518331e+02,
# ...

# %%
from sklearn import metrics

# %%
acc = metrics.r2_score(Y_test,y_predict)
print('Accuracy Score of Model: ', round(acc*100,2),'%')
# Out:
# Accuracy Score of Model:  99.99 %

# %%
# Actual v/s Predicted Price
price_prediction = pd.DataFrame({'Actual Price': Y_test, 'Predicted_Price': y_predict})
price_prediction
# Out:
#       Actual Price  Predicted_Price
# 582        5.83001        15.204031
# 2001     265.85000       272.287268
# 1259     101.89998       109.036534
# 2129     453.39000       463.951981
# 667        3.23000         3.925422
# ...            ...              ...
# 890        8.90000         9.925672
# 1355     206.85000       243.225568
# 563        8.71380        28.763702
# 1244      98.37516       104.329733
# 1347     179.71000       190.255199
#
# [582 rows x 2 columns]

# %%
# Model Evaluation
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test, y_predict))
print('Mean Squared Error:', metrics.mean_squared_error(Y_test, y_predict))
# Out:
# Mean Absolute Error: 13.303542924233655
# Mean Squared Error: 439.05559120810415

# %%
# Rounding off
print('Mean Absolute Error:', round(metrics.mean_absolute_error(Y_test, y_predict),2))
print('Mean Squared Error:', round(metrics.mean_squared_error(Y_test, y_predict),2))
# Out:
# Mean Absolute Error: 13.3
# Mean Squared Error: 439.06

# %% [markdown]
# ### The MSE of my model is 439.06
